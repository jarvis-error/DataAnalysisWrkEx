# %%
# Import packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Creating series ds from list

x=['Shreenidhi','Ganesh','Tarak','Mrithyunjay','Kevin']
name=pd.Series(x)
name
# Out:
# 0     Shreenidhi
# 1         Ganesh
# 2          Tarak
# 3    Mrithyunjay
# 4          Kevin
# dtype: object

# %%
# Creating json key:value pair in series

y={'Country':['India','Ireland','Denmark','Brazil','Italy']}
kv=pd.Series(y)
kv
# Out:
# Country    [India, Ireland, Denmark, Brazil, Italy]
# dtype: object

# %%
# Creating series ds from list

L=['English','Kannada','Hindi','Maths','Physics']
lang=pd.Series(L)
lang
# Out:
# 0    English
# 1    Kannada
# 2      Hindi
# 3      Maths
# 4    Physics
# dtype: object

# %%
# Series ds to DataFrame ds
NAMES=pd.DataFrame(name)
NAMES
# Out:
#              0
# 0   Shreenidhi
# 1       Ganesh
# 2        Tarak
# 3  Mrithyunjay
# 4        Kevin

# %%
# Series ds to DataFrame ds
kyvl=pd.DataFrame(kv)
kyvl
# Out:
#                                                 0
# Country  [India, Ireland, Denmark, Brazil, Italy]

# %%
# Series ds to DataFrame ds
language=pd.DataFrame(lang)
language
# Out:
#          0
# 0  English
# 1  Kannada
# 2    Hindi
# 3    Maths
# 4  Physics

# %%
# concatinate 2 DataFrames along columns (axis=1)

cnctc=pd.concat([NAMES,language],axis=1)
cnctc
# Out:
#              0        0
# 0   Shreenidhi  English
# 1       Ganesh  Kannada
# 2        Tarak    Hindi
# 3  Mrithyunjay    Maths
# 4        Kevin  Physics

# %%
# names for columns

cnctc.columns=['Names','Language']
cnctc
# Out:
#          Names Language
# 0   Shreenidhi  English
# 1       Ganesh  Kannada
# 2        Tarak    Hindi
# 3  Mrithyunjay    Maths
# 4        Kevin  Physics

# %%
# concatinate 2 DataFrames along rows (axis=0)

cnctr=pd.concat([NAMES,language],axis=0)
cnctr
# Out:
#              0
# 0   Shreenidhi
# 1       Ganesh
# 2        Tarak
# 3  Mrithyunjay
# 4        Kevin
# 0      English
# 1      Kannada
# 2        Hindi
# 3        Maths
# 4      Physics

# %%
# name for column
cnctr.columns=['Unknown']
cnctr
# Out:
#        Unknown
# 0   Shreenidhi
# 1       Ganesh
# 2        Tarak
# 3  Mrithyunjay
# 4        Kevin
# 0      English
# 1      Kannada
# 2        Hindi
# 3        Maths
# 4      Physics

# %%
# One liner for concating

oneliner=pd.DataFrame(list(zip(x,L)))
oneliner
# Out:
#              0        1
# 0   Shreenidhi  English
# 1       Ganesh  Kannada
# 2        Tarak    Hindi
# 3  Mrithyunjay    Maths
# 4        Kevin  Physics

# %%
# names for columns
oneliner.columns=['Names','Subject']
oneliner
# Out:
#          Names  Subject
# 0   Shreenidhi  English
# 1       Ganesh  Kannada
# 2        Tarak    Hindi
# 3  Mrithyunjay    Maths
# 4        Kevin  Physics

# %% [markdown]
# ## 19_8_21

# %%
# Index naming

country=['India','America','China','Africa','England']
cnty=pd.Series(country,index=['aa','bb','cc','dd','ee'])
cnty
# Out:
# aa      India
# bb    America
# cc      China
# dd     Africa
# ee    England
# dtype: object

# %%
cndf=pd.DataFrame(cnty)
cndf
# Out:
#           0
# aa    India
# bb  America
# cc    China
# dd   Africa
# ee  England

# %%
# Retrieve value based from index value

cnty['bb']
# Out:
# 'America'

# %%
# Retrieve value based from index value

cnty[['ee','dd']]
# Out:
# ee    England
# dd     Africa
# dtype: object

# %%
# Concat two DataFrames with different index value

n=['Akshay','Bharath','Chintan','Dobby','Elina','Farhan']
na=pd.Series(n)
na
# Out:
# 0     Akshay
# 1    Bharath
# 2    Chintan
# 3      Dobby
# 4      Elina
# 5     Farhan
# dtype: object

# %%
c=['Amazon','Google','Apple','Delloite','Microsoft']
co=pd.Series(c,index=['a','b','c','d','e'])
co
# Out:
# a       Amazon
# b       Google
# c        Apple
# d     Delloite
# e    Microsoft
# dtype: object

# %%
nam=pd.DataFrame(na)
nam
# Out:
#          0
# 0   Akshay
# 1  Bharath
# 2  Chintan
# 3    Dobby
# 4    Elina
# 5   Farhan

# %%
com=pd.DataFrame(co)
com
# Out:
#            0
# a     Amazon
# b     Google
# c      Apple
# d   Delloite
# e  Microsoft

# %%
# Concat two DataFrames with different index value along column

nacm=pd.concat([nam,com],axis=1)
nacm
# Out:
#          0          0
# 0   Akshay        NaN
# 1  Bharath        NaN
# 2  Chintan        NaN
# 3    Dobby        NaN
# 4    Elina        NaN
# 5   Farhan        NaN
# a      NaN     Amazon
# b      NaN     Google
# c      NaN      Apple
# d      NaN   Delloite
# e      NaN  Microsoft

# %%
# Concat two DataFrames with different index value along row

nacmrow=pd.concat([nam,com],axis=0)
nacmrow
# Out:
#            0
# 0     Akshay
# 1    Bharath
# 2    Chintan
# 3      Dobby
# 4      Elina
# 5     Farhan
# a     Amazon
# b     Google
# c      Apple
# d   Delloite
# e  Microsoft

# %%
# Slicing

nacm[1:'d']
# Out:
#          0         0
# 1  Bharath       NaN
# 2  Chintan       NaN
# 3    Dobby       NaN
# 4    Elina       NaN
# 5   Farhan       NaN
# a      NaN    Amazon
# b      NaN    Google
# c      NaN     Apple
# d      NaN  Delloite

# %%
# Reverse Slicing

nacm[::-1]
# Out:
#          0          0
# e      NaN  Microsoft
# d      NaN   Delloite
# c      NaN      Apple
# b      NaN     Google
# a      NaN     Amazon
# 5   Farhan        NaN
# 4    Elina        NaN
# 3    Dobby        NaN
# 2  Chintan        NaN
# 1  Bharath        NaN
# 0   Akshay        NaN

# %%
nacmrow[::-1]
# Out:
#            0
# e  Microsoft
# d   Delloite
# c      Apple
# b     Google
# a     Amazon
# 5     Farhan
# 4      Elina
# 3      Dobby
# 2    Chintan
# 1    Bharath
# 0     Akshay

# %%
nacmrow[2:'e']
# Out:
#            0
# 2    Chintan
# 3      Dobby
# 4      Elina
# 5     Farhan
# a     Amazon
# b     Google
# c      Apple
# d   Delloite
# e  Microsoft

# %%
n[0:2]
# Out:
# ['Akshay', 'Bharath']

# %%
print()

# %%
print(na)
# Out:
# 0     Akshay
# 1    Bharath
# 2    Chintan
# 3      Dobby
# 4      Elina
# 5     Farhan
# dtype: object

# %%
na.name='Students'
print(na)
print(type(na))
# Out:
# 0     Akshay
# 1    Bharath
# 2    Chintan
# 3      Dobby
# 4      Elina
# 5     Farhan
# Name: Students, dtype: object
# <class 'pandas.core.series.Series'>

# %%
nacm.columns=['Colums1','Column2']
nacm
# Out:
#    Colums1    Column2
# 0   Akshay        NaN
# 1  Bharath        NaN
# 2  Chintan        NaN
# 3    Dobby        NaN
# 4    Elina        NaN
# 5   Farhan        NaN
# a      NaN     Amazon
# b      NaN     Google
# c      NaN      Apple
# d      NaN   Delloite
# e      NaN  Microsoft

# %%
nacm.index.name='Index'
nacm
# Out:
#        Colums1    Column2
# Index
# 0       Akshay        NaN
# 1      Bharath        NaN
# 2      Chintan        NaN
# 3        Dobby        NaN
# 4        Elina        NaN
# 5       Farhan        NaN
# a          NaN     Amazon
# b          NaN     Google
# c          NaN      Apple
# d          NaN   Delloite
# e          NaN  Microsoft

# %%
nacm.columns
# Out:
# Index(['Colums1', 'Column2'], dtype='object')

# %%
nacm.values
# Out:
# array([['Akshay', nan],
#        ['Bharath', nan],
#        ['Chintan', nan],
#        ['Dobby', nan],
#        ['Elina', nan],
#        ['Farhan', nan],
#        [nan, 'Amazon'],
#        [nan, 'Google'],
#        [nan, 'Apple'],
#        [nan, 'Delloite'],
#        [nan, 'Microsoft']], dtype=object)

# %%
nacm.size
# Out:
# 22

# %%
nacm.empty
# Out:
# False

# %%
nacm.isnull()
# Out:
#        Colums1  Column2
# Index
# 0        False     True
# 1        False     True
# 2        False     True
# 3        False     True
# 4        False     True
# 5        False     True
# a         True    False
# b         True    False
# c         True    False
# d         True    False
# e         True    False

# %%
emp=['One','','']
empy=pd.Series(emp)
empy.empty
# Out:
# False

# %%
employ=pd.DataFrame()
employ.empty
# Out:
# True

# %%
emp1=['One','','']
emps=pd.Series(emp1)
emps1=pd.DataFrame(emps)
emps1
# Out:
#      0
# 0  One
# 1
# 2

# %%
emps1.isnull()
# Out:
#        0
# 0  False
# 1  False
# 2  False

# %% [markdown]
# ## 23/8/21

# %%
# Create table of 4 columns weather,temperature,humidity,rainy or not
# and with index name (days) of values from monday to sunday

I=['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','saturday']
W=['Sunny','Rainy','Cloudy','Cloudy and Rainy','Sunny and cloudy','Cloudy','Sunny']
T=['33C','19C','23C','23C','27C','25C','33']
H=['NA','NA','NA','NA','NA','NA','NA']
R=['No','Yes','No','Yes','No','No','No']
IS=pd.Series(I)
WS=pd.Series(W)
TS=pd.Series(T)
HS=pd.Series(H)
RS=pd.Series(R)
ID=pd.DataFrame(IS)
WD=pd.DataFrame(WS)
TD=pd.DataFrame(TS)
HD=pd.DataFrame(HS)
RD=pd.DataFrame(RS)
Z=pd.concat([WD,TD,HD,RD],axis=1)
Z.index=I
Z.index.name='Days'
Z.columns=['Weather','Temperature','Humidity','RainFall']
Z
# Out:
#                     Weather Temperature Humidity RainFall
# Days
# Sunday                Sunny         33C       NA       No
# Monday                Rainy         19C       NA      Yes
# Tuesday              Cloudy         23C       NA       No
# Wednesday  Cloudy and Rainy         23C       NA      Yes
# Thursday   Sunny and cloudy         27C       NA       No
# Friday               Cloudy         25C       NA       No
# saturday              Sunny          33       NA       No

# %%
# Retrieve information from DataFrame -----> 1. loc 2. iloc
# And ways to retrieve info-----> By 1.value, 2.list, 3.slicing, 4.conditions, 5.callable function

# 1.By Value
# By value(name)--------df.loc[row_value,column_value]
zz=Z.loc['Sunday','Temperature']
zz
# Out:
# '33C'

# %%
# By value(index) --------df.iloc[row_index_number,column_index_number]

yy=Z.iloc[0,1]
yy
# Out:
# '33C'

# %%
# 2. By list---> Value(name)
xx=Z.loc['Monday',['Weather','Temperature','RainFall']]
xx
# Out:
# Weather        Rainy
# Temperature      19C
# RainFall         Yes
# Name: Monday, dtype: object

# %%
# By index value
vv=Z.iloc[[1],[0,1,2,3]]
vv
# Out:
#        Weather Temperature Humidity RainFall
# Days
# Monday   Rainy         19C       NA      Yes

# %%
bv=Z.loc[['Monday','Wednesday','Friday'],['Weather','Temperature','RainFall']]
bv
# Out:
#                     Weather Temperature RainFall
# Days
# Monday                Rainy         19C      Yes
# Wednesday  Cloudy and Rainy         23C      Yes
# Friday               Cloudy         25C       No

# %%
av=Z.iloc[[1,2,3],[0]]
av
# Out:
#                     Weather
# Days
# Monday                Rainy
# Tuesday              Cloudy
# Wednesday  Cloudy and Rainy

# %%
# 3. By slicing 
# By value(name) 
# Slicing with value doesn't exclude last value i.e both Friday and RainFall are included

cv=Z.loc['Monday':'Friday','Weather':'RainFall']
cv
# Out:
#                     Weather Temperature Humidity RainFall
# Days
# Monday                Rainy         19C       NA      Yes
# Tuesday              Cloudy         23C       NA       No
# Wednesday  Cloudy and Rainy         23C       NA      Yes
# Thursday   Sunny and cloudy         27C       NA       No
# Friday               Cloudy         25C       NA       No

# %%
# Slicing with index numbers excludes last values i.e 6th and 3rd positioned values are excluded

dv=Z.iloc[0:6,0:3] 
dv
# Out:
#                     Weather Temperature Humidity
# Days
# Sunday                Sunny         33C       NA
# Monday                Rainy         19C       NA
# Tuesday              Cloudy         23C       NA
# Wednesday  Cloudy and Rainy         23C       NA
# Thursday   Sunny and cloudy         27C       NA
# Friday               Cloudy         25C       NA

# %%
# Slicing with value(name)
cv=Z.loc['Monday':'Thursday',:]
cv
# Out:
#                     Weather Temperature Humidity RainFall
# Days
# Monday                Rainy         19C       NA      Yes
# Tuesday              Cloudy         23C       NA       No
# Wednesday  Cloudy and Rainy         23C       NA      Yes
# Thursday   Sunny and cloudy         27C       NA       No

# %%
# Slicing with index number
dv=Z.iloc[0:4,:] 
dv
# Out:
#                     Weather Temperature Humidity RainFall
# Days
# Sunday                Sunny         33C       NA       No
# Monday                Rainy         19C       NA      Yes
# Tuesday              Cloudy         23C       NA       No
# Wednesday  Cloudy and Rainy         23C       NA      Yes

# %% [markdown]
# ## 24/8/21

# %%
# json format to create DataFrame
# import pandas as pd  
# import numpy as ny

All={'English':[88,87,77,66,87,86,77,88,77,65,83,55,54,99,90,89,89,99,87,67],
     'Kannada':[88,87,77,66,87,86,77,88,77,65,87,86,77,88,77,65,87,55,90,99],
     'Maths':[66,87,86,77,88,77,65,87,86,77,86,77,88,77,65,87,55,77,65,87],
     'Physics':[77,66,87,86,77,88,77,65,87,55,54,99,90,89,89,99,89,89,99,78],
     'Chemistry':[66,87,86,77,88,77,65,87,55,54,99,90,89,89,99,89,87,55,54,99],
     'Biology':[77,66,87,86,77,88,77,65,87,55,54,99,90,89,89,99,89,89,99,78]}
st=['Adam','Stark','Catherin','Devin','Elay','Fin','Gusto','Hela',
                           'Isiquel','Jack','Stark','Lisa','Mark','Neo','Oswald','Peggy','Queeny','Rose','Stark','Tony']
df=pd.DataFrame(All,index=st)
#df.index=st
df.index.name='Names'
df
# Out:
#           English  Kannada  Maths  Physics  Chemistry  Biology
# Names
# Adam           88       88     66       77         66       77
# Stark          87       87     87       66         87       66
# Catherin       77       77     86       87         86       87
# Devin          66       66     77       86         77       86
# Elay           87       87     88       77         88       77
# Fin            86       86     77       88         77       88
# Gusto          77       77     65       77         65       77
# Hela           88       88     87       65         87       65
# Isiquel        77       77     86       87         55       87
# Jack           65       65     77       55         54       55
# Stark          83       87     86       54         99       54
# Lisa           55       86     77       99         90       99
# Mark           54       77     88       90         89       90
# Neo            99       88     77       89         89       89
# ...

# %%
df.loc['Stark','English']
# Out:
# Names
# Stark    87
# Stark    83
# Stark    87
# Name: English, dtype: int64

# %% [markdown]
# ## 25/8/21

# %%
# groupby
# used to group all the values/specific values in DataFrame

# %%
# just creates the object of group 

df.groupby('Physics')

# %%
# By passing Physics column to 'groupby' it 'groups' every individual values  

df.groupby('Physics').groups
# Out:
# {54: ['Stark'], 55: ['Jack'], 65: ['Hela'], 66: ['Stark'], 77: ['Adam', 'Elay', 'Gusto'], 78: ['Tony'], 86: ['Devin'], 87: ['Catherin', 'Isiquel'], 88: ['Fin'], 89: ['Neo', 'Oswald', 'Queeny', 'Rose'], 90: ['Mark'], 99: ['Lisa', 'Peggy', 'Stark']}

# %%
# Using get_group with groupby we can group one specific value

df.groupby('Physics').get_group(89)
# Out:
#         English  Kannada  Maths  Physics  Chemistry  Biology
# Names
# Neo          99       88     77       89         89       89
# Oswald       90       77     65       89         99       89
# Queeny       89       87     55       89         87       89
# Rose         99       55     77       89         55       89

# %%
# Merge DataFrames 

A={'Emp_ID':[100,101,102,103,104,105,106,107],
   'Emp_Name':['Ash','Bin','Cath','Das','Eion','Fani','Gadop','George']}
B={'Emp_ID':[100,101,102,103,104,105,106],
   'Emp_Dept':['Physics','Chemistry','Maths','DataScience','English','Hindi','Kannada']}
C={'Emp_Name':['Ash','Bin','Cath','Das','Eion','Fani','Gadop','George'],
   'Emp_Salary':['100000','20000','15000','12000','18000','23000','56000','19000']}
AA=pd.DataFrame(A)
BB=pd.DataFrame(B)
CC=pd.DataFrame(C)

# %%
AB=pd.merge(AA,BB,on='Emp_ID',how='inner')
AB
# Out:
#    Emp_ID Emp_Name     Emp_Dept
# 0     100      Ash      Physics
# 1     101      Bin    Chemistry
# 2     102     Cath        Maths
# 3     103      Das  DataScience
# 4     104     Eion      English
# 5     105     Fani        Hindi
# 6     106    Gadop      Kannada

# %%
AB=pd.merge(AA,BB,on='Emp_ID',how='outer')
AB
# Out:
#    Emp_ID Emp_Name     Emp_Dept
# 0     100      Ash      Physics
# 1     101      Bin    Chemistry
# 2     102     Cath        Maths
# 3     103      Das  DataScience
# 4     104     Eion      English
# 5     105     Fani        Hindi
# 6     106    Gadop      Kannada
# 7     107   George          NaN

# %%
AB=pd.merge(AA,BB,on='Emp_ID',how='left')
AB
# Out:
#    Emp_ID Emp_Name     Emp_Dept
# 0     100      Ash      Physics
# 1     101      Bin    Chemistry
# 2     102     Cath        Maths
# 3     103      Das  DataScience
# 4     104     Eion      English
# 5     105     Fani        Hindi
# 6     106    Gadop      Kannada
# 7     107   George          NaN

# %%
AB=pd.merge(AA,BB,on='Emp_ID',how='right')
AB
# Out:
#    Emp_ID Emp_Name     Emp_Dept
# 0     100      Ash      Physics
# 1     101      Bin    Chemistry
# 2     102     Cath        Maths
# 3     103      Das  DataScience
# 4     104     Eion      English
# 5     105     Fani        Hindi
# 6     106    Gadop      Kannada

# %%
ABC=pd.merge(AB,CC,on='Emp_Name',how='outer')
ABC
# Out:
#    Emp_ID Emp_Name     Emp_Dept Emp_Salary
# 0   100.0      Ash      Physics     100000
# 1   101.0      Bin    Chemistry      20000
# 2   102.0     Cath        Maths      15000
# 3   103.0      Das  DataScience      12000
# 4   104.0     Eion      English      18000
# 5   105.0     Fani        Hindi      23000
# 6   106.0    Gadop      Kannada      56000
# 7     NaN   George          NaN      19000

# %%
ABC.loc[7,'Emp_ID']
# Out:
# nan

# %%
# To fill NAN values at all places

ABC.fillna('IGNORE THESE VALUES').astype(str)
# Out:
#                 Emp_ID Emp_Name             Emp_Dept Emp_Salary
# 0                100.0      Ash              Physics     100000
# 1                101.0      Bin            Chemistry      20000
# 2                102.0     Cath                Maths      15000
# 3                103.0      Das          DataScience      12000
# 4                104.0     Eion              English      18000
# 5                105.0     Fani                Hindi      23000
# 6                106.0    Gadop              Kannada      56000
# 7  IGNORE THESE VALUES   George  IGNORE THESE VALUES      19000

# %%
# So to fill this nan with values

ABC.Emp_ID.fillna(107).astype(int)
# Out:
# 0    100
# 1    101
# 2    102
# 3    103
# 4    104
# 5    105
# 6    106
# 7    107
# Name: Emp_ID, dtype: int32

# %%
# Here main DataFrame is not affected as we are not assigning

ABC
# Out:
#    Emp_ID Emp_Name     Emp_Dept Emp_Salary
# 0   100.0      Ash      Physics     100000
# 1   101.0      Bin    Chemistry      20000
# 2   102.0     Cath        Maths      15000
# 3   103.0      Das  DataScience      12000
# 4   104.0     Eion      English      18000
# 5   105.0     Fani        Hindi      23000
# 6   106.0    Gadop      Kannada      56000
# 7     NaN   George          NaN      19000

# %%
# To solve previous problem i.e assigning

ABC.Emp_Dept=ABC.Emp_Dept.fillna('AI/ML').astype(str)
ABC
# Out:
#    Emp_ID Emp_Name     Emp_Dept Emp_Salary
# 0   100.0      Ash      Physics     100000
# 1   101.0      Bin    Chemistry      20000
# 2   102.0     Cath        Maths      15000
# 3   103.0      Das  DataScience      12000
# 4   104.0     Eion      English      18000
# 5   105.0     Fani        Hindi      23000
# 6   106.0    Gadop      Kannada      56000
# 7     NaN   George        AI/ML      19000
